# %% [markdown]
# # Funkcje

# %% [markdown]
# ## Podstawy

# %% [markdown]
# Defniowanie funkcji

# %%
def sum_of_powers(l, n):
    s = 0
    for elem in l:
        s = s + elem**n
    return s

print(sum_of_powers([1,2,3],3))

# %% [markdown]
# Argumenty nazwane (keyword arguments)

# %%
sum_of_powers(n=3, l=[1,2,3])

# %% [markdown]
# Domyślne wartości argumentów

# %%
def sum_of_powers(l, n=3):
    s = 0
    for elem in l:
        s = s + elem**n
    return s

print(sum_of_powers([1,2,3]))

# %% [markdown]
# Zwracanie wartości z funkcji

# %%
def sum_of_powers(l, n):
    s = 0
    for elem in l:
        s = s + elem**n
    print(s)
    # return

print(sum_of_powers([1,2,3],3))

# %% [markdown]
# Wartość specjalna - None

# %%
print(type(None))

def sum_of_powers(l, n):
    if len(l) == 0:
        return None
    else:
        s = 0
        for elem in l:
            s = s + elem**n
        return s

print(sum_of_powers([1,2,3],3))
print(sum_of_powers([],3))

# %%
s = sum_of_powers([],3)
if s:
    print("suma:",s)
else:
    print("pusta lista")

# %% [markdown]
# Zwracanie "kilku wartości"

# %%
def sum_of_powers(l, n):
    if len(l) == 0:
        return None
    else:
        s = 0
        for elem in l:
            s = s + elem**n
        return s,n

print(sum_of_powers([1,2,3],3))
print(type(sum_of_powers([1,2,3],3)))

# %%
s1,n1 = sum_of_powers([1,2,3],3)
print("suma:",s1)
print("potega:",n1)

# %% [markdown]
# "Pusta" funkcja

# %%
def empty():
    pass

print(empty())

# %% [markdown]
# Zmienna liczba argumentów
# \* - operator pakowania do krotki

# %%
def sum_of_powers(n,*l):
    s = 0
    for elem in l:
        s = s + elem**n
    return s

print(sum_of_powers(3,1,2,3))
print(sum_of_powers(3,1,2,3,4,5))
# Out:
# 36
# 225

# %% [markdown]
# asterisk \* jako operator rozpakowywania

# %%
l = [1,2,3]
# sum_of_powers(3,l)
sum_of_powers(3,*l)

# %% [markdown]
# Pakowanie argumentów nazwanych - **

# %%
def sum_of_powers(**kwargs):

    print(kwargs)
    if 'n' in kwargs:
        n = kwargs['n']
    else:
        m="potęga 'n' nieokreślona"
        return m
    if 'l' in kwargs:
        l = kwargs['l']
    else:
        m="lista liczb 'l' nieokreślona"
        return m

    if len(l) == 0:
        m="pusta lista liczb"
        return m
    else:
        s = 0
        for elem in l:
            s = s + elem**n
        return s

r = sum_of_powers(n=3, l=[1,2,3])
if type(r) == str:
    print("wiadomość:\n",r)
else:
    print("suma: ",r)

# %%
r = sum_of_powers(l=[1,2,3])
if type(r) == str:
    print("wiadomość:\n",r)
else:
    print("suma: ",r)

# %%
r = sum_of_powers(n=3)
if type(r) == str:
    print("wiadomość:\n",r)
else:
    print("suma: ",r)

# %% [markdown]
# Rozpakowywanie argumentów nazwanych - **

# %%
d = {'n':3,
     'l':[1,2,3]}
# r = sum_of_powers(d)
r = sum_of_powers(**d)
if type(r) == str:
    print("wiadomość:\n",r)
else:
    print("suma: ",r)

# %% [markdown]
# Dokumentacja funkcji w kodzie

# %%
def sum_of_powers(l, n):
    """ Oblicza sumę n-tych potęg liczb w liście l """
    if len(l) == 0:
        return None
    else:
        s = 0
        for elem in l:
            s = s + elem**n
        return s,n

help(sum_of_powers)

# %%
sum_of_powers.__doc__

# %% [markdown]
# Adnotacje

# %%
def sum_of_powers(l: list, n: int) -> float:
    """ Oblicza sumę n-tych potęg liczb w liście l """
    if len(l) == 0:
        return None
    else:
        s = 0
        for elem in l:
            s = s + elem**n
        return s,n

sum_of_powers.__annotations__

# %% [markdown]
# ## Wyrażenia lambda, map(), filter()

# %%
l = [x for x in range(1,101)]
l2 = [(x,x**3) for x in l if x % 7==0 and x%2 != 0]
print(l2)
# Out:
# [(7, 343), (21, 9261), (35, 42875), (49, 117649), (63, 250047), (77, 456533), (91, 753571)]

# %%
fmap = lambda x: (x,x**3)
filt = lambda x: x % 7==0 and x%2 != 0

l = [x for x in range(1,101)]
l2 = [fmap(x) for x in l if filt(x)]
print(l2)
# Out:
# [(7, 343), (21, 9261), (35, 42875), (49, 117649), (63, 250047), (77, 456533), (91, 753571)]

# %%
fmap = lambda x: (x,x**3)
filt = lambda x: x % 7==0 and x%2 != 0

l = [x for x in range(1,101)]

f = filter(filt,l)
print(f)
lf = list(f)
print(lf)

m = map(fmap, lf)
print(m)
lm = list(m)
print(lm)
# Out:
# <filter object at 0x000002B72B3BE920>
# [7, 21, 35, 49, 63, 77, 91]
# <map object at 0x000002B72B723100>
# [(7, 343), (21, 9261), (35, 42875), (49, 117649), (63, 250047), (77, 456533), (91, 753571)]

# %%
fmap = lambda x: (x,x**3)
filt = lambda x: x % 7==0 and x%2 != 0

l = [x for x in range(1,101)]

l1 = list(map(fmap, filter(filt,l)))
print(l1)
# Out:
# [(7, 343), (21, 9261), (35, 42875), (49, 117649), (63, 250047), (77, 456533), (91, 753571)]

# %% [markdown]
# ## Funkcje wyższego rzędu

# %%
def strangePow(x,n):
    return (x+1)**(n-1)

def strPowN(n):
    def cPow(x):
        return strangePow(x,n)
    return cPow

a3 = strPowN(3)
a3(2)

l = [strPowN(n) for n in range(1,5)]
print(l)

n=3
ln = [f(n) for f in l]
print(ln)
# Out:
# [<function strPowN.<locals>.cPow at 0x000002B72B8CF910>, <function strPowN.<locals>.cPow at 0x000002B729FE8040>, <function strPowN.<locals>.cPow at 0x000002B729FE80D0>, <function strPowN.<locals>.cPow at 0x000002B729FE8160>]
# [1, 4, 16, 64]
